# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi227-sakshi/Leet-Code-solution-CPP/blob/main/sms_spam_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/sms-spam-classifier/spam_email_dataset.csv', encoding='latin1')

print(df.head())
# Out:
#                                        Subject  \
# 0  Exclusive Loan Offer  Get Instant Approval
# 1                  Meeting Agenda for Tomorrow
# 2              Quarterly Sales Report Attached
# 3  Exclusive Loan Offer  Get Instant Approval
# 4     Win $1,000,000 Now  Limited Time Offer!
#
#                                                 Body  Spam Label
# 0  Alert!\n\nYour computer has been infected with...           1
# 1  Dear Student,\n\nThis is a reminder about your...           0
# 2  Hey,\n\nIm sharing the travel itinerary for o...           0
# 3  Dear Investor,\n\nDon't miss this incredible i...           1
# 4  Dear Customer,\n\nWe are giving away free holi...           1

# %%
df.shape
# Out:
# (1500, 3)

# %%
#1. Data Cleaning
#2. EDA
#3. TExt Preprocessing
#4. model building
#5. Evaluation
#6. improvement
#7 website
#8 Deploy

# %%
print(df.columns)
# Out:
# Index(['Subject', 'Body', 'Spam Label'], dtype='object')

# %% [markdown]
# 1 Data Cleaning

# %%
# drop Last 3 cols
df.drop(columns=['Unnamed: 2'], inplace=True, errors='ignore')

# %%
df.sample(5)
# Out:
#                                          Subject  \
# 799   Great Meetup Yesterday  Lets Plan Again!
# 1113              Upcoming Online Class Reminder
# 536              Order Confirmation  Thank You!
# 1104                 Thank You for Your Support!
# 761          Work From Home & Earn $10,000/Week!
#
#                                                    Body  Spam Label
# 799   Hello,\n\nYour recent purchase from our store ...           0
# 1113  Hello,\n\nYour password has been successfully ...           0
# 536   Dear Student,\n\nThis is a reminder about your...           0
# 1104  Dear Mark,\n\nI wanted to personally thank you...           0
# 761   Dear Investor,\n\nDon't miss this incredible i...           1

# %%
#remaining the cols
df.rename(columns={'v1':'target', 'v2':'text'}, inplace=True)
df.sample(5)
# Out:
#                                             Subject  \
# 1103                    Meeting Agenda for Tomorrow
# 1069       Win $1,000,000 Now  Limited Time Offer!
# 922                 Quarterly Sales Report Attached
# 785             Work From Home & Earn $10,000/Week!
# 17    Security Alert! Your Amazon Account Is Locked
#
#                                                    Body  Spam Label
# 1103  Dear Team,\n\nPlease find the attached report ...           0
# 1069  Dear Valued Customer,\n\nYou have won a grand ...           1
# 922   Dear Mark,\n\nI wanted to personally thank you...           0
# 785   Dear Customer,\n\nWe are giving away free holi...           1
# 17    Dear Valued Customer,\n\nYou have won a grand ...           1

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df.head()
# Out:
#                                        Subject  \
# 0  Exclusive Loan Offer  Get Instant Approval
# 1                  Meeting Agenda for Tomorrow
# 2              Quarterly Sales Report Attached
# 3  Exclusive Loan Offer  Get Instant Approval
# 4     Win $1,000,000 Now  Limited Time Offer!
#
#                                                 Body  Spam Label
# 0  Alert!\n\nYour computer has been infected with...           1
# 1  Dear Student,\n\nThis is a reminder about your...           0
# 2  Hey,\n\nIm sharing the travel itinerary for o...           0
# 3  Dear Investor,\n\nDon't miss this incredible i...           1
# 4  Dear Customer,\n\nWe are giving away free holi...           1

# %%
#missing val
df.isnull().sum()
# Out:
# Subject       0
# Body          0
# Spam Label    0
# dtype: int64

# %%
#chack for duplicated val
df.duplicated().sum()
# Out:
# np.int64(1301)

# %%
df = df.drop_duplicates(keep = 'first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (199, 3)
